# %%
import folium
import json
from utils import get_solution_coords
from data import possible_locations, current_locations


def visualize_solution(result_file_name, possible_locations=possible_locations):
    with open("./results/" + result_file_name + ".json") as f:
        result = json.load(f)
        solution = result["solution"]
        fitness = result["fitness"]
        voronoi_polygons = result["voronoi_polygons"]
        solution_coords = result["solution_coords"]

    print("Fitness: ", fitness, ", Containers: ", solution.count(1))

    # Create map
    map = folium.Map(
        location=list([39.47345473371031, -0.3772689881177383]),
        tiles="cartodbpositron",
        zoom_start=14,
    )
    containers_group = folium.FeatureGroup(name="Containers Blue").add_to(map)
    voronoi_group = folium.FeatureGroup(name="Voronoi").add_to(map)
    folium.LayerControl().add_to(map)

    for location in solution_coords:
        # Add marker
        folium.Marker(
            location=list(reversed(location)),
            icon=folium.Icon(icon="dumpster", prefix="fa"),
            # tooltip="",
        ).add_to(containers_group)

    for polygon in voronoi_polygons:
        folium.GeoJson(
            polygon,
            # tooltip=,
            style_function=lambda feature: {
                "fillColor": "#ffff00",
            },
        ).add_to(voronoi_group)
    return map

# %% [markdown]
# # Current solution

# %%
visualize_solution("current", possible_locations=current_locations)
# Out:
# Fitness:  297238 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddeeced0d2a25bceed1daa7137af0bc6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddeeced0d2a25bceed1daa7137af0bc6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddeeced0d2a25bceed1daa7137af0bc6 = L.map(
#                 &quot;map_ddeeced0d2a25bceed1daa7137af0bc6&quot;,
#                 {
#                     center: [39.47345473371031, -0.3772689881177383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b7893a86d2abf0647d041cb85181d25 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6b7893a86d2abf0647d041cb85181d25.addTo(map_ddeeced0d2a25bceed1daa7137af0bc6);
#
#
#             var feature_group_b5439bd14d790778c8638beb3a37cb3c = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_5e4c5b5ff65c26f0bb4a8389d5dfebf2 = L.marker(
#                 [39.478164703085184, -0.3834991044482499],
#                 {}
#             ).addTo(feature_group_b5439bd14d790778c8638beb3a37cb3c);
#
#
#             var icon_56580555198032dcab2c58de8e3b043d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5e4c5b5ff65c26f0bb4a8389d5dfebf2.setIcon(icon_56580555198032dcab2c58de8e3b043d);
#
#
#             var marker_5bc0b217d17786318c9b86e0680171c2 = L.marker(
#                 [39.46112152046048, -0.3520073459198504],
#                 {}
#             ).addTo(feature_group_b5439bd14d790778c8638beb3a37cb3c);
#
#
#             var icon_d85e7c2ed9558db07252c80c565e0215 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5bc0b217d17786318c9b86e0680171c2.setIcon(icon_d85e7c2ed9558db07252c80c565e0215);
#
#
#             var marker_b216f84d426b9ed206a3fb09dda7bd70 = L.marker(
#                 [39.48700952293332, -0.3927993965757745],
#                 {}
#             ).addTo(feature_group_b5439bd14d790778c8638beb3a37cb3c);
#
#
#             var icon_24fc1b19ea56aea42af37b26576b3c99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b216f84d426b9ed206a3fb09dda7bd70.setIcon(icon_24fc1b19ea56aea42af37b26576b3c99);
#
#
#             var marker_0a661e7ea5992c3dcc4c82ff31f2b146 = L.marker(
#                 [39.46808530153522, -0.3772980467911945],
#                 {}
#             ).addTo(feature_group_b5439bd14d790778c8638beb3a37cb3c);
#
#
#             var icon_8bfdbe3f1e1a5503819804d2c8d8df13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0a661e7ea5992c3dcc4c82ff31f2b146.setIcon(icon_8bfdbe3f1e1a5503819804d2c8d8df13);
#
#
#             var marker_930a03cd502471e31ebd047f8f6bf0d6 = L.marker(
#                 [39.49895515142951, -0.3883010517909016],
#                 {}
#             ).addTo(feature_group_b5439bd14d790778c8638beb3a37cb3c);
#
#
#             var icon_eac8381c09bffa147b7375e1a870d75f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_930a03cd502471e31ebd047f8f6bf0d6.setIcon(icon_eac8381c09bffa147b7375e1a870d75f);
#
#
#             var marker_9781a5ff5eb67e0e296502a934774efe = L.marker(
#                 [39.47364910567398, -0.3611717379539136],
#                 {}
#             ).addTo(feature_group_b5439bd14d790778c8638beb3a37cb3c);
#
#
#             var icon_72930ad0f7372e4d329aa32bb714060d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             mark

# %% [markdown]
# # Overlap Heuristic

# %%
visualize_solution("max_population_heuristic")
# Out:
# Fitness:  374616 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7153c740c070ff54ddde2edd04e9055d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7153c740c070ff54ddde2edd04e9055d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7153c740c070ff54ddde2edd04e9055d = L.map(
#                 &quot;map_7153c740c070ff54ddde2edd04e9055d&quot;,
#                 {
#                     center: [39.47345473371031, -0.3772689881177383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1862fec1733eca9f9067a15c98b8010 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e1862fec1733eca9f9067a15c98b8010.addTo(map_7153c740c070ff54ddde2edd04e9055d);
#
#
#             var feature_group_828d0ca047f661da86a322f9a768fb2f = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_d88941f3192bde747d42304f3ce7fbff = L.marker(
#                 [39.458884349884904, -0.3929362450018165],
#                 {}
#             ).addTo(feature_group_828d0ca047f661da86a322f9a768fb2f);
#
#
#             var icon_6ffd6999d1ed4f9816c02099ffdc5c5d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d88941f3192bde747d42304f3ce7fbff.setIcon(icon_6ffd6999d1ed4f9816c02099ffdc5c5d);
#
#
#             var marker_a16f69f6786368ba1f1eeb923ca04b59 = L.marker(
#                 [39.45861420288878, -0.392863154342952],
#                 {}
#             ).addTo(feature_group_828d0ca047f661da86a322f9a768fb2f);
#
#
#             var icon_8d7dd692c1ad90a854851c56afd192b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a16f69f6786368ba1f1eeb923ca04b59.setIcon(icon_8d7dd692c1ad90a854851c56afd192b7);
#
#
#             var marker_0ab2460812a03dd5e519b54f962f6936 = L.marker(
#                 [39.459546718165114, -0.3992682701204914],
#                 {}
#             ).addTo(feature_group_828d0ca047f661da86a322f9a768fb2f);
#
#
#             var icon_93094f973fe107f0ba6ab1074036c430 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0ab2460812a03dd5e519b54f962f6936.setIcon(icon_93094f973fe107f0ba6ab1074036c430);
#
#
#             var marker_d536507084930336d21e7e0ab820cd2a = L.marker(
#                 [39.45461198924966, -0.39218388441631385],
#                 {}
#             ).addTo(feature_group_828d0ca047f661da86a322f9a768fb2f);
#
#
#             var icon_7c30ae0a499e82a4fa4e028f1da70822 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d536507084930336d21e7e0ab820cd2a.setIcon(icon_7c30ae0a499e82a4fa4e028f1da70822);
#
#
#             var marker_67d9e43436257fb3f048437139b62780 = L.marker(
#                 [39.45389427684329, -0.39909392558869444],
#                 {}
#             ).addTo(feature_group_828d0ca047f661da86a322f9a768fb2f);
#
#
#             var icon_b59346f2dd5a6ee4b5d530de9937a225 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_67d9e43436257fb3f048437139b62780.setIcon(icon_b59346f2dd5a6ee4b5d530de9937a225);
#
#
#             var marker_0f8dfafb4f700cfb154afd5684276007 = L.marker(
#                 [39.4635430579154, -0.3889035433004184],
#                 {}
#             ).addTo(feature_group_828d0ca047f661da86a322f9a768fb2f);
#
#
#             var icon_985ed6fe5aa2b479694caa59d8a2e858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             mar

# %% [markdown]
# # Most populated heuristic

# %%
visualize_solution("max_population_min_overlap_heuristic")
# Out:
# Fitness:  260021 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d64ed9c6f33f8abc0ad286c5379c21e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d64ed9c6f33f8abc0ad286c5379c21e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d64ed9c6f33f8abc0ad286c5379c21e3 = L.map(
#                 &quot;map_d64ed9c6f33f8abc0ad286c5379c21e3&quot;,
#                 {
#                     center: [39.47345473371031, -0.3772689881177383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6eb6c323a4b8a309e82e9d9066199e1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6eb6c323a4b8a309e82e9d9066199e1.addTo(map_d64ed9c6f33f8abc0ad286c5379c21e3);
#
#
#             var feature_group_4fd08e0aa241f70f5bb8e82fed5f502f = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_ad2bb393f0d8b7ea6d1c65fabbee97a5 = L.marker(
#                 [39.46787440102438, -0.41340954611580216],
#                 {}
#             ).addTo(feature_group_4fd08e0aa241f70f5bb8e82fed5f502f);
#
#
#             var icon_e23f1dee9554d45c42b5743fa852fb50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ad2bb393f0d8b7ea6d1c65fabbee97a5.setIcon(icon_e23f1dee9554d45c42b5743fa852fb50);
#
#
#             var marker_fc20eb02c2d0972dea48fbc6ff0cd92f = L.marker(
#                 [39.458884349884904, -0.3929362450018165],
#                 {}
#             ).addTo(feature_group_4fd08e0aa241f70f5bb8e82fed5f502f);
#
#
#             var icon_fc734c09d61ee1b9e784f3d4e5f6bbad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fc20eb02c2d0972dea48fbc6ff0cd92f.setIcon(icon_fc734c09d61ee1b9e784f3d4e5f6bbad);
#
#
#             var marker_d3b67a9182785abcd5f1eccc33c35c54 = L.marker(
#                 [39.43884532083406, -0.38981935531433315],
#                 {}
#             ).addTo(feature_group_4fd08e0aa241f70f5bb8e82fed5f502f);
#
#
#             var icon_c9c565a3671c8e73bbb3ce34c17baa07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d3b67a9182785abcd5f1eccc33c35c54.setIcon(icon_c9c565a3671c8e73bbb3ce34c17baa07);
#
#
#             var marker_5ef5180acdfaa4a3a75cb389b4658461 = L.marker(
#                 [39.46742714674655, -0.37774622456446727],
#                 {}
#             ).addTo(feature_group_4fd08e0aa241f70f5bb8e82fed5f502f);
#
#
#             var icon_85dcae8f0e6a7461477a94c7fec508f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5ef5180acdfaa4a3a75cb389b4658461.setIcon(icon_85dcae8f0e6a7461477a94c7fec508f2);
#
#
#             var marker_071e5a288dac8d2d049ff4e5980e67b9 = L.marker(
#                 [39.457010263061655, -0.3976758717770986],
#                 {}
#             ).addTo(feature_group_4fd08e0aa241f70f5bb8e82fed5f502f);
#
#
#             var icon_a27b41b361785aba033761634bf025f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_071e5a288dac8d2d049ff4e5980e67b9.setIcon(icon_a27b41b361785aba033761634bf025f5);
#
#
#             var marker_8bb5a5a2ff62d96650fcf3be3acab1f5 = L.marker(
#                 [39.44080465088216, -0.3901755808507649],
#                 {}
#             ).addTo(feature_group_4fd08e0aa241f70f5bb8e82fed5f502f);
#
#
#             var icon_2900541d6036ebcea95ce8d4ccf2388c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
