# %%
import folium
import json
from utils import get_solution_coords
from data import possible_locations, current_locations


def visualize_solution(result_file_name, possible_locations=possible_locations):
    with open("./results/" + result_file_name + ".json") as f:
        result = json.load(f)
        solution = result["solution"]
        fitness = result["fitness"]
        voronoi_polygons = result["voronoi_polygons"]
        solution_coords = result["solution_coords"]

    print("Fitness: ", fitness, ", Containers: ", solution.count(1))

    # Create map
    map = folium.Map(
        location=list([39.47490354629992, -0.37609998916904364]),
        tiles="cartodbpositron",
        zoom_start=13,
    )
    containers_group = folium.FeatureGroup(name="Containers Blue").add_to(map)
    voronoi_group = folium.FeatureGroup(name="Voronoi").add_to(map)
    folium.LayerControl().add_to(map)

    for location in solution_coords:
        # Add marker
        folium.Marker(
            location=list(reversed(location)),
            icon=folium.Icon(icon="dumpster", prefix="fa"),
            # tooltip="",
        ).add_to(containers_group)

    for polygon in voronoi_polygons:
        folium.GeoJson(
            polygon,
            # tooltip=,
            style_function=lambda feature: {
                "fillColor": "#ffff00",
            },
        ).add_to(voronoi_group)
    return map

# %% [markdown]
# # Current solution

# %%
visualize_solution("current", possible_locations=current_locations)
# Out:
# Fitness:  297238 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12343a3789e56e33664e991fc83beaa8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12343a3789e56e33664e991fc83beaa8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12343a3789e56e33664e991fc83beaa8 = L.map(
#                 &quot;map_12343a3789e56e33664e991fc83beaa8&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce9bf42c3740de8372902461c1e3a9e1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ce9bf42c3740de8372902461c1e3a9e1.addTo(map_12343a3789e56e33664e991fc83beaa8);
#
#
#             var feature_group_f1369f98c1ed542d7b9a8184204fc813 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_c756047a24a18b533dea35e4121f82ec = L.marker(
#                 [39.478164703085184, -0.3834991044482499],
#                 {}
#             ).addTo(feature_group_f1369f98c1ed542d7b9a8184204fc813);
#
#
#             var icon_b0aff9580f134623817b9f37e4a18b88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c756047a24a18b533dea35e4121f82ec.setIcon(icon_b0aff9580f134623817b9f37e4a18b88);
#
#
#             var marker_5da2eb7b4df71448fb31556f9858682f = L.marker(
#                 [39.46112152046048, -0.3520073459198504],
#                 {}
#             ).addTo(feature_group_f1369f98c1ed542d7b9a8184204fc813);
#
#
#             var icon_8a6e272199a7680a9347ccf7c833e1ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5da2eb7b4df71448fb31556f9858682f.setIcon(icon_8a6e272199a7680a9347ccf7c833e1ff);
#
#
#             var marker_b5745b12eab365b154f3cb40a0dced00 = L.marker(
#                 [39.48700952293332, -0.3927993965757745],
#                 {}
#             ).addTo(feature_group_f1369f98c1ed542d7b9a8184204fc813);
#
#
#             var icon_12be842cfb54086753019ed9702e9e32 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b5745b12eab365b154f3cb40a0dced00.setIcon(icon_12be842cfb54086753019ed9702e9e32);
#
#
#             var marker_6f9df131f98239f84070f5a76c8ba53d = L.marker(
#                 [39.46808530153522, -0.3772980467911945],
#                 {}
#             ).addTo(feature_group_f1369f98c1ed542d7b9a8184204fc813);
#
#
#             var icon_d3509eb98b58cd3745790c506b6e7b44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6f9df131f98239f84070f5a76c8ba53d.setIcon(icon_d3509eb98b58cd3745790c506b6e7b44);
#
#
#             var marker_7082e2302438db175abbeaf6e8453f52 = L.marker(
#                 [39.49895515142951, -0.3883010517909016],
#                 {}
#             ).addTo(feature_group_f1369f98c1ed542d7b9a8184204fc813);
#
#
#             var icon_9a120d3f800ca6243ff3f90973193034 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7082e2302438db175abbeaf6e8453f52.setIcon(icon_9a120d3f800ca6243ff3f90973193034);
#
#
#             var marker_f873dd1ce11d8dd05abe6e02b6571bae = L.marker(
#                 [39.47364910567398, -0.3611717379539136],
#                 {}
#             ).addTo(feature_group_f1369f98c1ed542d7b9a8184204fc813);
#
#
#             var icon_64e3e45c84eff07d40b37661ceb352f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             mar

# %% [markdown]
# # Overlap Heuristic

# %%
visualize_solution("max_population_heuristic")
# Out:
# Fitness:  374616 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4cb5c46f5f4fe309ac2ac77c4c91f02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4cb5c46f5f4fe309ac2ac77c4c91f02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4cb5c46f5f4fe309ac2ac77c4c91f02 = L.map(
#                 &quot;map_f4cb5c46f5f4fe309ac2ac77c4c91f02&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b35d276601993c60cc0a8689e5576956 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b35d276601993c60cc0a8689e5576956.addTo(map_f4cb5c46f5f4fe309ac2ac77c4c91f02);
#
#
#             var feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_5b62c42311ee33538afb61a3c39f7f66 = L.marker(
#                 [39.458884349884904, -0.3929362450018165],
#                 {}
#             ).addTo(feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1);
#
#
#             var icon_bb3ceaf87d630296403c849fd11f4120 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5b62c42311ee33538afb61a3c39f7f66.setIcon(icon_bb3ceaf87d630296403c849fd11f4120);
#
#
#             var marker_575c256375e4d5a8730f1c5cea738db8 = L.marker(
#                 [39.45861420288878, -0.392863154342952],
#                 {}
#             ).addTo(feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1);
#
#
#             var icon_20a80f439301686628d84e1a355cf28b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_575c256375e4d5a8730f1c5cea738db8.setIcon(icon_20a80f439301686628d84e1a355cf28b);
#
#
#             var marker_4241907220ab92e3d964830d5737aa2b = L.marker(
#                 [39.459546718165114, -0.3992682701204914],
#                 {}
#             ).addTo(feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1);
#
#
#             var icon_5b5b0a69236376dfbee0c7a65c96d7d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4241907220ab92e3d964830d5737aa2b.setIcon(icon_5b5b0a69236376dfbee0c7a65c96d7d4);
#
#
#             var marker_19520e9c8decf720b012ebe33c7a9da2 = L.marker(
#                 [39.45461198924966, -0.39218388441631385],
#                 {}
#             ).addTo(feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1);
#
#
#             var icon_576d626b61e4a1afbfc5a0db78af6d68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_19520e9c8decf720b012ebe33c7a9da2.setIcon(icon_576d626b61e4a1afbfc5a0db78af6d68);
#
#
#             var marker_e4a3e5e2f75aab4b6b5215862ae13d2e = L.marker(
#                 [39.45389427684329, -0.39909392558869444],
#                 {}
#             ).addTo(feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1);
#
#
#             var icon_8dc3ad5b1b2da5571bcf627388bac545 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e4a3e5e2f75aab4b6b5215862ae13d2e.setIcon(icon_8dc3ad5b1b2da5571bcf627388bac545);
#
#
#             var marker_b5946cfe7d518b8ba880b3c5609fdaa4 = L.marker(
#                 [39.4635430579154, -0.3889035433004184],
#                 {}
#             ).addTo(feature_group_d8c13251cbfc4bbcb7a21255aa7af2c1);
#
#
#             var icon_faa33aad07f5d7217342110ae6639e84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             ma

# %% [markdown]
# # Most populated heuristic

# %%
visualize_solution("max_population_min_overlap_heuristic")
# Out:
# Fitness:  260021 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_646e734a5692276f9d4b90b0319346b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_646e734a5692276f9d4b90b0319346b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_646e734a5692276f9d4b90b0319346b8 = L.map(
#                 &quot;map_646e734a5692276f9d4b90b0319346b8&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_515a15d1a6aa4c4ea8851b957a0d995a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_515a15d1a6aa4c4ea8851b957a0d995a.addTo(map_646e734a5692276f9d4b90b0319346b8);
#
#
#             var feature_group_3fdf51bd39ee2ecea86579246e9a5dba = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_8e4ef1f6406bb5abc779078702e485f5 = L.marker(
#                 [39.46787440102438, -0.41340954611580216],
#                 {}
#             ).addTo(feature_group_3fdf51bd39ee2ecea86579246e9a5dba);
#
#
#             var icon_51d47e63e262601de2144a40d803fa0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8e4ef1f6406bb5abc779078702e485f5.setIcon(icon_51d47e63e262601de2144a40d803fa0d);
#
#
#             var marker_4b962a54208723b5baf4ba5f5b62b5bf = L.marker(
#                 [39.458884349884904, -0.3929362450018165],
#                 {}
#             ).addTo(feature_group_3fdf51bd39ee2ecea86579246e9a5dba);
#
#
#             var icon_eee8186259e2a785e952f981bc2fab29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4b962a54208723b5baf4ba5f5b62b5bf.setIcon(icon_eee8186259e2a785e952f981bc2fab29);
#
#
#             var marker_643751b87cece4675198153937149e7e = L.marker(
#                 [39.43884532083406, -0.38981935531433315],
#                 {}
#             ).addTo(feature_group_3fdf51bd39ee2ecea86579246e9a5dba);
#
#
#             var icon_4c5977c0671770e9e9559eec1e558a13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_643751b87cece4675198153937149e7e.setIcon(icon_4c5977c0671770e9e9559eec1e558a13);
#
#
#             var marker_ad3dce125a305555557784a76c40b627 = L.marker(
#                 [39.46742714674655, -0.37774622456446727],
#                 {}
#             ).addTo(feature_group_3fdf51bd39ee2ecea86579246e9a5dba);
#
#
#             var icon_7dace2bc34cccbf4498a09d0afbe4bca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ad3dce125a305555557784a76c40b627.setIcon(icon_7dace2bc34cccbf4498a09d0afbe4bca);
#
#
#             var marker_7fcf29c8cbc6a17002a4b8a64d17b3eb = L.marker(
#                 [39.457010263061655, -0.3976758717770986],
#                 {}
#             ).addTo(feature_group_3fdf51bd39ee2ecea86579246e9a5dba);
#
#
#             var icon_f3f1121219c46d78d8a0fa716d8543d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7fcf29c8cbc6a17002a4b8a64d17b3eb.setIcon(icon_f3f1121219c46d78d8a0fa716d8543d1);
#
#
#             var marker_e29256b0d8aab92a8244c64a6b1e7337 = L.marker(
#                 [39.44080465088216, -0.3901755808507649],
#                 {}
#             ).addTo(feature_group_3fdf51bd39ee2ecea86579246e9a5dba);
#
#
#             var icon_510b28b06e73ea0ee7512cbb9c8ce0c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
