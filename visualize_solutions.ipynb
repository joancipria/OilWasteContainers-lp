# %%
import folium
import json
from utils import get_solution_coords
from data import possible_locations, current_locations


def visualize_solution(result_file_name, possible_locations=possible_locations):
    with open("./results/" + result_file_name + ".json") as f:
        result = json.load(f)
        solution = result["solution"]
        fitness = result["fitness"]
        voronoi_polygons = result["voronoi_polygons"]
        solution_coords = result["solution_coords"]

    print("Fitness: ", fitness, ", Containers: ", solution.count(1))

    # Create map
    map = folium.Map(
        location=list([39.47490354629992, -0.37609998916904364]),
        tiles="cartodbpositron",
        zoom_start=13,
    )
    containers_group = folium.FeatureGroup(name="Containers Blue").add_to(map)
    voronoi_group = folium.FeatureGroup(name="Voronoi").add_to(map)
    folium.LayerControl().add_to(map)

    for location in solution_coords:
        # Add marker
        folium.Marker(
            location=list(reversed(location)),
            icon=folium.Icon(icon="dumpster", prefix="fa"),
            # tooltip="",
        ).add_to(containers_group)

    for polygon in voronoi_polygons:
        folium.GeoJson(
            polygon,
            # tooltip=,
            style_function=lambda feature: {
                "fillColor": "#ffff00",
            },
        ).add_to(voronoi_group)
    return map

# %% [markdown]
# # Current solution

# %%
visualize_solution("current", possible_locations=current_locations)
# Out:
# Fitness:  297238 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d60058f4ce87eb3304506bba08560dc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d60058f4ce87eb3304506bba08560dc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d60058f4ce87eb3304506bba08560dc3 = L.map(
#                 &quot;map_d60058f4ce87eb3304506bba08560dc3&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c5f763a86d07b75bb0b9b8adb6f3d8a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9c5f763a86d07b75bb0b9b8adb6f3d8a.addTo(map_d60058f4ce87eb3304506bba08560dc3);
#
#
#             var feature_group_faf8026cee2efae1f0fc2de7ba87c044 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_14215c599923dc9c260ae7cd6a46c065 = L.marker(
#                 [39.478164703085184, -0.3834991044482499],
#                 {}
#             ).addTo(feature_group_faf8026cee2efae1f0fc2de7ba87c044);
#
#
#             var icon_72ae59cefbae9b1bf5a8569f2304c089 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_14215c599923dc9c260ae7cd6a46c065.setIcon(icon_72ae59cefbae9b1bf5a8569f2304c089);
#
#
#             var marker_8f0b7d7988288e237926652de58f02b8 = L.marker(
#                 [39.46112152046048, -0.3520073459198504],
#                 {}
#             ).addTo(feature_group_faf8026cee2efae1f0fc2de7ba87c044);
#
#
#             var icon_f3cf1e7058788d140661413028aa2182 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8f0b7d7988288e237926652de58f02b8.setIcon(icon_f3cf1e7058788d140661413028aa2182);
#
#
#             var marker_eeb4b34ccff4f43bafc71d733cc83ed7 = L.marker(
#                 [39.48700952293332, -0.3927993965757745],
#                 {}
#             ).addTo(feature_group_faf8026cee2efae1f0fc2de7ba87c044);
#
#
#             var icon_a3d5ff70d94e393b9730a9f42e7b46ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eeb4b34ccff4f43bafc71d733cc83ed7.setIcon(icon_a3d5ff70d94e393b9730a9f42e7b46ce);
#
#
#             var marker_23904f8506fc8026af4d0c67933261ba = L.marker(
#                 [39.46808530153522, -0.3772980467911945],
#                 {}
#             ).addTo(feature_group_faf8026cee2efae1f0fc2de7ba87c044);
#
#
#             var icon_76c4126af08ceeb4f0e22b4d0c7ac954 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_23904f8506fc8026af4d0c67933261ba.setIcon(icon_76c4126af08ceeb4f0e22b4d0c7ac954);
#
#
#             var marker_18ac35229d679a5b6c80cc5e418148ec = L.marker(
#                 [39.49895515142951, -0.3883010517909016],
#                 {}
#             ).addTo(feature_group_faf8026cee2efae1f0fc2de7ba87c044);
#
#
#             var icon_4f0b3832f07e2670a36b22587bb5db46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_18ac35229d679a5b6c80cc5e418148ec.setIcon(icon_4f0b3832f07e2670a36b22587bb5db46);
#
#
#             var marker_3002e9ca8260d66e10aafd91805aeef2 = L.marker(
#                 [39.47364910567398, -0.3611717379539136],
#                 {}
#             ).addTo(feature_group_faf8026cee2efae1f0fc2de7ba87c044);
#
#
#             var icon_c8e7851f518041e75fd5844c0741fbe7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             mar

# %% [markdown]
# # Overlap Heuristic

# %%
visualize_solution("max_population_heuristic")
# Out:
# Fitness:  374616 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b52ce1ffde022bece50d77853b74517 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b52ce1ffde022bece50d77853b74517&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b52ce1ffde022bece50d77853b74517 = L.map(
#                 &quot;map_2b52ce1ffde022bece50d77853b74517&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c25ca2dbb7bad18b181dd285a091cc9f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c25ca2dbb7bad18b181dd285a091cc9f.addTo(map_2b52ce1ffde022bece50d77853b74517);
#
#
#             var feature_group_9e8f6db15d81ab51c3f39b69de7caf1e = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_1d1e70cc41b947aa8ba3e1e68e5cd881 = L.marker(
#                 [39.458884349884904, -0.3929362450018165],
#                 {}
#             ).addTo(feature_group_9e8f6db15d81ab51c3f39b69de7caf1e);
#
#
#             var icon_f41bcf7240a9114639fff070992960b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1d1e70cc41b947aa8ba3e1e68e5cd881.setIcon(icon_f41bcf7240a9114639fff070992960b7);
#
#
#             var marker_b33511af68d893f2871d71bba81035aa = L.marker(
#                 [39.45861420288878, -0.392863154342952],
#                 {}
#             ).addTo(feature_group_9e8f6db15d81ab51c3f39b69de7caf1e);
#
#
#             var icon_82518fd386d4f597c7c59863918e7e0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b33511af68d893f2871d71bba81035aa.setIcon(icon_82518fd386d4f597c7c59863918e7e0c);
#
#
#             var marker_1286a9965e49272ba3d7726806274a7f = L.marker(
#                 [39.459546718165114, -0.3992682701204914],
#                 {}
#             ).addTo(feature_group_9e8f6db15d81ab51c3f39b69de7caf1e);
#
#
#             var icon_237315777b3d18908b24767addd854af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1286a9965e49272ba3d7726806274a7f.setIcon(icon_237315777b3d18908b24767addd854af);
#
#
#             var marker_49844323d1bd73999cedc44d8a7b18a3 = L.marker(
#                 [39.45461198924966, -0.39218388441631385],
#                 {}
#             ).addTo(feature_group_9e8f6db15d81ab51c3f39b69de7caf1e);
#
#
#             var icon_bf8201ed86e94c2e4c4291770c41f527 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_49844323d1bd73999cedc44d8a7b18a3.setIcon(icon_bf8201ed86e94c2e4c4291770c41f527);
#
#
#             var marker_82264c902e0798a8ba7634e8d1389f0d = L.marker(
#                 [39.45389427684329, -0.39909392558869444],
#                 {}
#             ).addTo(feature_group_9e8f6db15d81ab51c3f39b69de7caf1e);
#
#
#             var icon_a233a1ac9d64f6a60a7e67be05e382a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_82264c902e0798a8ba7634e8d1389f0d.setIcon(icon_a233a1ac9d64f6a60a7e67be05e382a1);
#
#
#             var marker_dd50e02ac5d1644b0923dba8b1a08f24 = L.marker(
#                 [39.4635430579154, -0.3889035433004184],
#                 {}
#             ).addTo(feature_group_9e8f6db15d81ab51c3f39b69de7caf1e);
#
#
#             var icon_cb2dd2550944e1fb83d8574459c4f8c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             ma

# %% [markdown]
# # Most populated heuristic

# %%
visualize_solution("max_population_min_overlap_heuristic")
# Out:
# Fitness:  260021 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b150c11707fd4948ce3c0212b3ecc355 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b150c11707fd4948ce3c0212b3ecc355&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b150c11707fd4948ce3c0212b3ecc355 = L.map(
#                 &quot;map_b150c11707fd4948ce3c0212b3ecc355&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8cdfe221354dd8ffbc7c3f7e537ac68 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8cdfe221354dd8ffbc7c3f7e537ac68.addTo(map_b150c11707fd4948ce3c0212b3ecc355);
#
#
#             var feature_group_8eb681f41fbf2bd862f2520ae042b681 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_e6525b3abe3635713c68e5776375595f = L.marker(
#                 [39.46787440102438, -0.41340954611580216],
#                 {}
#             ).addTo(feature_group_8eb681f41fbf2bd862f2520ae042b681);
#
#
#             var icon_b4c832aac7fd374961259c623b9e59ab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e6525b3abe3635713c68e5776375595f.setIcon(icon_b4c832aac7fd374961259c623b9e59ab);
#
#
#             var marker_6dcf8389b3d2fb9c43694771c6c27869 = L.marker(
#                 [39.458884349884904, -0.3929362450018165],
#                 {}
#             ).addTo(feature_group_8eb681f41fbf2bd862f2520ae042b681);
#
#
#             var icon_56402761e4f9bd5f459ce92c6afde4db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6dcf8389b3d2fb9c43694771c6c27869.setIcon(icon_56402761e4f9bd5f459ce92c6afde4db);
#
#
#             var marker_b6a72058a79ed2c143bfa9cf055e7169 = L.marker(
#                 [39.43884532083406, -0.38981935531433315],
#                 {}
#             ).addTo(feature_group_8eb681f41fbf2bd862f2520ae042b681);
#
#
#             var icon_19fbd073cb4f3cb98b0c9e5e1f0c212a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b6a72058a79ed2c143bfa9cf055e7169.setIcon(icon_19fbd073cb4f3cb98b0c9e5e1f0c212a);
#
#
#             var marker_3ee8bed020fd66569505ca497c4c97a3 = L.marker(
#                 [39.46742714674655, -0.37774622456446727],
#                 {}
#             ).addTo(feature_group_8eb681f41fbf2bd862f2520ae042b681);
#
#
#             var icon_6e34e6a4d29d84b33931ea47f9621638 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ee8bed020fd66569505ca497c4c97a3.setIcon(icon_6e34e6a4d29d84b33931ea47f9621638);
#
#
#             var marker_df22336639d7638ed75fa28f884fb5da = L.marker(
#                 [39.457010263061655, -0.3976758717770986],
#                 {}
#             ).addTo(feature_group_8eb681f41fbf2bd862f2520ae042b681);
#
#
#             var icon_5ac83894eda19b2fdc6aa9e7e1bc99a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_df22336639d7638ed75fa28f884fb5da.setIcon(icon_5ac83894eda19b2fdc6aa9e7e1bc99a6);
#
#
#             var marker_03180cf4884746ec50ba30747fd56ba2 = L.marker(
#                 [39.44080465088216, -0.3901755808507649],
#                 {}
#             ).addTo(feature_group_8eb681f41fbf2bd862f2520ae042b681);
#
#
#             var icon_65582047e4014a392288c9b25846248f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );

# %% [markdown]
# # GA (random init) solution

# %%
visualize_solution("ga_random_1")
# Out:
# Fitness:  239799 , Containers:  352
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c91cd5b129557b9f6ec321e88002034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c91cd5b129557b9f6ec321e88002034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c91cd5b129557b9f6ec321e88002034 = L.map(
#                 &quot;map_9c91cd5b129557b9f6ec321e88002034&quot;,
#                 {
#                     center: [39.47490354629992, -0.37609998916904364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b4b83073b8f3431d4c22c3bfbc58b73 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b4b83073b8f3431d4c22c3bfbc58b73.addTo(map_9c91cd5b129557b9f6ec321e88002034);
#
#
#             var feature_group_94f11fd68cbdaecb5cabfc59cf08a080 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_31f165b2d720d58921227dcf8f02eead = L.marker(
#                 [39.443810794813956, -0.38939581411087987],
#                 {}
#             ).addTo(feature_group_94f11fd68cbdaecb5cabfc59cf08a080);
#
#
#             var icon_f521d8b201a260b3c47226bbb14cf909 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_31f165b2d720d58921227dcf8f02eead.setIcon(icon_f521d8b201a260b3c47226bbb14cf909);
#
#
#             var marker_b25f68d3b9cf5618f4f9d5bb11eae33c = L.marker(
#                 [39.432417585619, -0.34308825329535236],
#                 {}
#             ).addTo(feature_group_94f11fd68cbdaecb5cabfc59cf08a080);
#
#
#             var icon_71623473e3cf8309d931d30dbcdb074a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b25f68d3b9cf5618f4f9d5bb11eae33c.setIcon(icon_71623473e3cf8309d931d30dbcdb074a);
#
#
#             var marker_36b3743bf35f07ad5e9d800781d6b9ae = L.marker(
#                 [39.464488863456346, -0.3629699345781083],
#                 {}
#             ).addTo(feature_group_94f11fd68cbdaecb5cabfc59cf08a080);
#
#
#             var icon_ff2ac0f34539f034ae8f066e5fc14969 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_36b3743bf35f07ad5e9d800781d6b9ae.setIcon(icon_ff2ac0f34539f034ae8f066e5fc14969);
#
#
#             var marker_2016e0781e2d69bdd8678db4243d7b49 = L.marker(
#                 [39.461120756648995, -0.3760774732270662],
#                 {}
#             ).addTo(feature_group_94f11fd68cbdaecb5cabfc59cf08a080);
#
#
#             var icon_a3c95d6b18a9864f5e65e2ce120f3e21 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2016e0781e2d69bdd8678db4243d7b49.setIcon(icon_a3c95d6b18a9864f5e65e2ce120f3e21);
#
#
#             var marker_d188b10448f3e6bbf91a3e76e2ceac8b = L.marker(
#                 [39.46732805889279, -0.3757028834328113],
#                 {}
#             ).addTo(feature_group_94f11fd68cbdaecb5cabfc59cf08a080);
#
#
#             var icon_4a891ea9e66dbd28d1aa20e295181102 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d188b10448f3e6bbf91a3e76e2ceac8b.setIcon(icon_4a891ea9e66dbd28d1aa20e295181102);
#
#
#             var marker_dc4b63aa0b4c7bbfa740383a73ca2f60 = L.marker(
#                 [39.477964504427575, -0.3817855134355893],
#                 {}
#             ).addTo(feature_group_94f11fd68cbdaecb5cabfc59cf08a080);
#
#
#             var icon_a002cb03d1816bc8f140589d1a5269dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dumpster&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
