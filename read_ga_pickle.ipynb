# %%
import pandas as pd

pickle_file = pd.read_pickle('./results/ga_random_1.pickle')
df = pd.DataFrame(pickle_file)
df
# Out:
# {'gen': 0, 'nevals': 500, 'avg': 308026.808, 'std': 4930.17070689606, 'min': 291162.0, 'max': 321736.0}
# {'gen': 1, 'nevals': 394, 'avg': 587005.486, 'std': 295965.83152089326, 'min': 291162.0, 'max': 900000.0}
# {'gen': 2, 'nevals': 419, 'avg': 582942.052, 'std': 295039.18331617804, 'min': 291162.0, 'max': 900000.0}
# {'gen': 3, 'nevals': 413, 'avg': 559394.282, 'std': 292278.51867971156, 'min': 291162.0, 'max': 900000.0}
# {'gen': 4, 'nevals': 435, 'avg': 549108.028, 'std': 290152.3896012287, 'min': 291162.0, 'max': 900000.0}
# {'gen': 5, 'nevals': 412, 'avg': 530655.082, 'std': 286755.47806161136, 'min': 293889.0, 'max': 900000.0}
# {'gen': 6, 'nevals': 435, 'avg': 516085.51, 'std': 283007.5306124236, 'min': 291571.0, 'max': 900000.0}
# {'gen': 7, 'nevals': 410, 'avg': 512096.118, 'std': 282199.9535772394, 'min': 291571.0, 'max': 900000.0}
# {'gen': 8, 'nevals': 410, 'avg': 521244.824, 'std': 285357.50695683656, 'min': 290648.0, 'max': 900000.0}
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(1)

plt.plot(df['gen'], df['min'])

plt.ylabel('Average minimum objective value')  # Etiqueta del eje x
plt.xlabel('Generation')               # Etiqueta del eje y

plt.show()
